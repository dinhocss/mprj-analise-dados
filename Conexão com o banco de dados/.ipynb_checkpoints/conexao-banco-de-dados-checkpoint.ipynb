# %%
import pandas as pd
from sqlalchemy import create_engine
from getpass import getpass
from urllib.parse import quote_plus

pd.set_option('display.max_columns', None)

# %%
host = 'aws-1-us-east-1.pooler.supabase.com'.strip()
port = '5432'.strip()
database = 'postgres'.strip()
user = 'candidato.jdazostyahhxukbmxybw'.strip()
password = 'DesafioInov@2026!'
password_cod = quote_plus(password)

connection_string = f"postgresql+psycopg2://{user}:{password_cod}@{host}:{port}/{database}"

try:
    engine = create_engine(connection_string)
    with engine.connect() as connection:
        print("Conexão bem-sucedida!")
except Exception as e:
    print(f"Erro ao conectar: {e}")

# %%
'''
Questão 1: Existem pagamentos sem empenho associado?
'''

query_pagamentos = """
SELECT * FROM pagamento
WHERE id_empenho IS NULL;
"""

df_resultado = pd.read_sql(query_pagamentos, engine)

print("Quantidade de pagamentos sem empenho:")
display(df_resultado)
# Out:
# Quantidade de pagamentos sem empenho:
# Empty DataFrame
# Columns: [id_empenho, id_pagamento, datapagamentoempenho, valor]
# Index: []

# %%
'''
Questão 2: Existem liquidações sem empenho vinculado?
'''

query_liq = """
SELECT * FROM liquidacao_nota_fiscal
WHERE id_empenho IS NULL
"""

df_resultado = pd.read_sql(query_liq, engine)

print("Quantidade de liquidações sem empenho:")
display(df_resultado)
# Out:
# Quantidade de liquidações sem empenho:
# Empty DataFrame
# Columns: [id_liquidacao_empenhonotafiscal, chave_danfe, data_emissao, valor, id_empenho]
# Index: []

# %%
'''
Questão 3: Existem empenhos sem contrato?
'''

query_emp = """
SELECT * FROM empenho
WHERE id_contrato IS NULL
"""

df_resultado = pd.read_sql(query_emp, engine)

print("Quantidade de empenhos sem contrato:")
display(df_resultado)
# Out:
# Quantidade de empenhos sem contrato:
# Empty DataFrame
# Columns: [id_empenho, ano, data_empenho, cpfcnpjcredor, credor, valor, id_entidade, id_contrato]
# Index: []

# %%
'''
Questão 4: Existem empenhos sem entidade?
'''

query_empenho = """
SELECT * FROM empenho
WHERE id_entidade IS NULL
"""

df_resultado = pd.read_sql(query_empenho, engine)

print("Quantidade de empenhos sem entidade:")
display(df_resultado)
# Out:
# Quantidade de empenhos sem entidade:
# Empty DataFrame
# Columns: [id_empenho, ano, data_empenho, cpfcnpjcredor, credor, valor, id_entidade, id_contrato]
# Index: []

# %%
'''
Questão 5: Existem contratos sem entidade ou fornecedor?
'''

query_contratos = """
SELECT * FROM contrato
WHERE id_contrato IS NULL
"""

query_forn = """
SELECT * FROM contrato
WHERE id_fornecedor IS NULL
"""

df_resultado = pd.read_sql(query_contratos, engine)
df_resultado2 = pd.read_sql(query_forn, engine)

print("Quantidade de contratos sem entidade:")
display(df_resultado)
print("Quantidade de contratos sem fornecedores:")
display(df_resultado2)
# Out:
# Quantidade de contratos sem entidade:
# Empty DataFrame
# Columns: [id_contrato, valor, data, objeto, id_entidade, id_fornecedor]
# Index: []
# Quantidade de contratos sem fornecedores:
# Empty DataFrame
# Columns: [id_contrato, valor, data, objeto, id_entidade, id_fornecedor]
# Index: []

# %%
'''
Questão 6: O valor de algum contrato é maior que o valor empenhado para a despesa pública?
'''

query_contrato = """
SELECT id_contrato, valor as valor_teto_contrato FROM contrato
"""

query_empenho = """
SELECT id_empenho, id_contrato, valor as valor_reservado_empenho FROM empenho
"""

df_contratos = pd.read_sql(query_contrato, engine)
df_empenhos = pd.read_sql(query_empenho, engine)

analise_teto = pd.merge(df_contratos, df_empenhos, on = 'id_contrato', how='inner')

contratos = analise_teto[analise_teto['valor_reservado_empenho'] > analise_teto['valor_teto_contrato']]

print(f"Empenhos que estouraram o valor do contrato: {len(contratos)}")
display(contratos)
# Out:
# Empenhos que estouraram o valor do contrato: 150
#      id_contrato  valor_teto_contrato id_empenho  valor_reservado_empenho
# 0           1001             20980.58      EMP-1                 34617.96
# 1           1002             26021.35     EMP-10                 42935.23
# 2           1003             25384.45    EMP-100                 41884.34
# 3           1004             15924.19    EMP-101                 26274.91
# 4           1005             30930.82    EMP-102                 51035.85
# ..           ...                  ...        ...                      ...
# 145         1146              8662.18    EMP-230                 14292.60
# 146         1147             48827.01    EMP-231                 80564.57
# 147         1148             37448.38    EMP-232                 61789.83
# 148         1149              7040.31    EMP-233                 11616.51
# 149         1150             36763.38    EMP-234                 60659.58
#
# [150 rows x 4 columns]

# %%
query_investigacao_total = """
SELECT 
    -- Selecionando colunas da tabela Pagamento (apelido 'p')
    p.id_pagamento,
    p.datapagamentoemp. AS data_pagamento,
    p.valor AS valor_pago,
    
    -- Selecionando colunas da tabela Empenho (apelido 'e')
    e.id_empenho,
    e.valor AS valor_empenhado,
    
    -- Selecionando colunas da tabela Contrato (apelido 'c')
    c.id_contrato,
    c.valor AS valor_teto_contrato

FROM pagamento p
-- 1. Costurando Pagamento com Empenho
INNER JOIN empenho e ON p.id_empenho = e.id_empenho

-- 2. Costurando o resultado disso com Contrato
INNER JOIN contrato c ON e.id_contrato = c.id_contrato
"""

df_raio_x = pd.read_sql(query_investigacao_total, engine)
display(df_raio_x)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# UndefinedTable: missing FROM-clause entry for table "datapagamentoemp"
# LINE 5:     p.datapagamentoemp. AS data_pagamento,
#             ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\sql.py:1679, in SQLDatabase.execute(self, sql, params)
#    1678 try:
# -> 1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) missing FROM-clause entry for table "datapagamentoemp"
# LINE 5:     p.datapagamentoemp. AS data_pagamento,
#             ^
#
# [SQL:
# SELECT
#     -- Selecionando colunas da tabela Pagamento (apelido 'p')
#     p.id_pagamento,
#     p.datapagamentoemp. AS data_pagamento,
#     p.valor AS valor_pago,
#
#     -- Selecionando colunas da tabela Empenho (apelido 'e')
#     e.id_empenho,
#     e.valor AS valor_empenhado,
#
#     -- Selecionando colunas da tabela Contrato (apelido 'c')
#     c.id_contrato,
#     c.valor AS valor_teto_contrato
#
# FROM pagamento p
# -- 1. Costurando Pagamento com Empenho
# INNER JOIN empenho e ON p.id_empenho = e.id_empenho
#
# -- 2. Costurando o resultado disso com Contrato
# INNER JOIN contrato c ON e.id_contrato = c.id_contrato
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[69], line 24
#       1 query_investigacao_total = """
#       2 SELECT
#       3     -- Selecionando colunas da tabela Pagamento (apelido 'p')
#    (...)     21 INNER JOIN contrato c ON e.id_contrato = c.id_contrato
#      22 """
# ---> 24 df_raio_x = pd.read_sql(query_investigacao_total, engine)
#      25 display(df_raio_x)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\sql.py:730, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     720     return pandas_sql.read_table(
#     721         sql,
#     722         index_col=index_col,
#    (...)    727         dtype_backend=dtype_backend,
#     728     )
#     729 else:
# --> 730     return pandas_sql.read_query(
#     731         sql,
#     732         index_col=index_col,
#     733         params=params,
#     734         coerce_float=coerce_float,
#     735         parse_dates=parse_dates,
#     736         chunksize=chunksize,
#     737         dtype_backend=dtype_backend,
#     738         dtype=dtype,
#     739     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\sql.py:1856, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1801 def read_query(
#    1802     self,
#    1803     sql: str,
#    (...)   1810     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1811 ) -> DataFrame | Iterator[DataFrame]:
#    1812     """
#    1813     Read SQL query into a DataFrame.
#    1814
#    (...)   1854
#    1855     """
# -> 1856     result = self.execute(sql, params)
#    1857     columns = result.keys()
#    1859     if chunksize is not None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\sql.py:1681, in SQLDatabase.execute(self, sql, params)
#    1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
# -> 1681     raise DatabaseError(f"Execution failed on sql '{sql}': {exc}") from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     -- Selecionando colunas da tabela Pagamento (apelido 'p')
#     p.id_pagamento,
#     p.datapagamentoemp. AS data_pagamento,
#     p.valor AS valor_pago,
#
#     -- Selecionando colunas da tabela Empenho (apelido 'e')
#     e.id_empenho,
#     e.valor AS valor_empenhado,
#
#     -- Selecionando colunas da tabela Contrato (apelido 'c')
#     c.id_contrato,
#     c.valor AS valor_teto_contrato
#
# FROM pagamento p
# -- 1. Costurando Pagamento com Empenho
# INNER JOIN empenho e ON p.id_empenho = e.id_empenho
#
# -- 2. Costurando o resultado disso com Contrato
# INNER JOIN contrato c ON e.id_contrato = c.id_contrato
# ': (psycopg2.errors.UndefinedTable) missing FROM-clause entry for table "datapagamentoemp"
# LINE 5:     p.datapagamentoemp. AS data_pagamento,
#             ^
#
# [SQL:
# SELECT
#     -- Selecionando colunas da tabela Pagamento (apelido 'p')
#     p.id_pagamento,
#     p.datapagamentoemp. AS data_pagamento,
#     p.valor AS valor_pago,
#
#     -- Selecionando colunas da tabela Empenho (apelido 'e')
#     e.id_empenho,
#     e.valor AS valor_empenhado,
#
#     -- Selecionando colunas da tabela Contrato (apelido 'c')
#     c.id_contrato,
#     c.valor AS valor_teto_contrato
#
# FROM pagamento p
# -- 1. Costurando Pagamento com Empenho
# INNER JOIN empenho e ON p.id_empenho = e.id_empenho
#
# -- 2. Costurando o resultado disso com Contrato
# INNER JOIN contrato c ON e.id_contrato = c.id_contrato
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
